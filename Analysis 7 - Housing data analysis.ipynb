# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts

# %% [markdown]
# <font size=5>California</font>

# %%
#Set file path and read into csv file
file_path = "data/zhvi_data.csv"
home_values_df=pd.read_csv(file_path)

# home_values_df.head()

# %%
# sort by states of interest: CA, TX, FL and maybe create new dataframes 
ca_filter=home_values_df['State']=="CA"
ca_df=home_values_df[ca_filter]
# display(ca_df)

# %%
# ca_df.describe()

# %%
price_columns= ['2017-01-31', '2017-02-28', '2017-03-31',
       '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
       '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
       '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30',
       '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
       '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
       '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
       '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29',
       '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
       '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31']

# %%
# Create a line plot showing ZHVI for LA County
la_cnt_filter=home_values_df['RegionName']=="Los Angeles County"

la_price_over_time=ca_df.loc[la_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,la_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Los Angeles County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=560000, ymax=750000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/la_single_zhvi.png')
plt.show()

# %%
# Create a line plot showing ZHVI in San Bernardino County

# go through to find row where RegionName=San Bernardino County, and pull all the date values then graph. 
sanbern_cnt_filter=home_values_df['RegionName']=="San Bernardino County"

sanbern_price_over_time=ca_df.loc[sanbern_cnt_filter, price_columns]

# display(sanbern_price_over_time.iloc[0])

plt.figure(figsize=(12,8))
plt.plot(price_columns,sanbern_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("San Bernardino County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/sanbernadino_single_zhvi.png')
plt.show()

# %%
# Create a line plot showing ZHVI in Riverside County


# go through to find row where RegionName=San Bernardino County, and pull all the date values then graph. 
riverside_cnt_filter=home_values_df['RegionName']=="Riverside County"

riverside_price_over_time=ca_df.loc[riverside_cnt_filter, price_columns]

# display(sanbern_price_over_time.iloc[0])

plt.figure(figsize=(12,8))
plt.plot(price_columns,riverside_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Riverside County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/riverside_single_zhvi.png')
plt.show()

# %%
#Create stacked plot showing ZHVI of all three counties

plt.figure(figsize=(12,8))
plt.plot(price_columns,riverside_price_over_time.iloc[0], label="Riverside County")
plt.plot(price_columns,sanbern_price_over_time.iloc[0], label="San Bernardino County")
plt.plot(price_columns,la_price_over_time.iloc[0], label="Los Angeles County")

plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("California Counties with High Covid Rates Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/tri_county_zhvi.png')
plt.show()

# %%
# create a stacked line chart showing the primary county and all the surrounding counties

inyo_filter=home_values_df['RegionName']=="Inyo County"
inyo_price_over_time=ca_df.loc[inyo_filter, price_columns]

tulare_filter=home_values_df['RegionName']=="Tulare County"
tulare_price_over_time=ca_df.loc[tulare_filter, price_columns]

kern_filter=home_values_df['RegionName']=="Kern County"
kern_price_over_time=ca_df.loc[kern_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,inyo_price_over_time.iloc[0], label="Inyo County")
plt.plot(price_columns,tulare_price_over_time.iloc[0], label="Tulare County")
plt.plot(price_columns,kern_price_over_time.iloc[0], label="Kern County")
plt.plot(price_columns,sanbern_price_over_time.iloc[0], label="San Bernardino County", linewidth=5.0)


plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("San Bernadino Surrounding Counties Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/sanbernadino_metro_zhvi.png')

plt.show()

# %%
# Figure 2: riverside + sandiego, imperial, and orange (other surrounding county is san bernardino)


sandiego_filter=home_values_df['RegionName']=="San Diego County"
sandiego_price_over_time=ca_df.loc[sandiego_filter, price_columns]

imperial_filter=home_values_df['RegionName']=="Imperial County"
imperial_price_over_time=ca_df.loc[imperial_filter, price_columns]

orange_filter=home_values_df['RegionName']=="Orange County"
orange_price_over_time=ca_df.loc[orange_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,sandiego_price_over_time.iloc[0], label="San Diego County")
plt.plot(price_columns,imperial_price_over_time.iloc[0], label="Imperial County")
plt.plot(price_columns,orange_price_over_time.iloc[0], label="Orange County")
plt.plot(price_columns,riverside_price_over_time.iloc[0], label="Riverside County", linewidth=5.0)


plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Riverside and surrounding Counties Home Values 2017-2020")
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.xticks(fontsize=8,rotation=90)
plt.legend()
plt.savefig('output/riverside_metro_zhvi.png')
plt.show()

# %%
# figure3: la county + orange, san bernardino, kern, ventura


ventura_filter=home_values_df['RegionName']=="Ventura County"
ventura_price_over_time=ca_df.loc[ventura_filter, price_columns]


plt.figure(figsize=(12,8))
plt.plot(price_columns,kern_price_over_time.iloc[0], label="Kern County")
plt.plot(price_columns,ventura_price_over_time.iloc[0], label="Ventura County")
plt.plot(price_columns,orange_price_over_time.iloc[0], label="Orange County")
plt.plot(price_columns,sanbern_price_over_time.iloc[0], label="San Bernardino County")
plt.plot(price_columns,la_price_over_time.iloc[0], label="Los Angeles County", linewidth=5.0)

plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Los Angeles County and surrounding Counties Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=200000, ymax=800000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend()
plt.savefig('output/los_angeles_metro_zhvi.png')
plt.show()

# %% [markdown]
# <font size=5>California continued:</font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
file_path = ('data/zhvi_data.csv')
data = pd.read_csv(file_path)
# data.head()

# %%
ca_filter=data['State']=="CA"
ca_df=data[ca_filter]
# display(ca_df)

# %%
ca_percent_cols=ca_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
la_counties=["Ventura County", "Kern County", "Inyo County", "San Diego County", "Orange County", "Riverside County", "San Bernardino County", "Imperial County"]

pre_covid=[]
covid=[]

for each_county in la_counties:
    ca_cnt_filter=ca_percent_cols['RegionName']==each_county  #just change county name and run cell
    
    mar2017=ca_percent_cols.loc[ca_cnt_filter,'2017-03-31']
    feb2020=ca_percent_cols.loc[ca_cnt_filter,'2020-02-29']
    mar2020=ca_percent_cols.loc[ca_cnt_filter,'2020-03-31']
    dec2020=ca_percent_cols.loc[ca_cnt_filter,'2020-12-31']
    
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((((dec2020-mar2020)/dec2020)/10)*10)*100).values[0]

    pre_covid.append(pre_covid_annual)
    covid.append(covid_annual)
    
# display(pre_covid)
# display(covid)

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":[2.6173834357597148,
 4.1422928313942196,
 0.058820244252640604,
 4.086479988917577,
 2.8368331840590106,
 4.379312344175799,
 4.731998368276424,
 4.347876886587158],
    
    "During Covid Value Change":[5.783607913882453,
 9.071388766567035,
 2.0131369753212156,
 9.320062180899265,
 6.074336168843511,
 8.378100769909011,
 8.696766633710498,
 7.8978192648264]
    
    }, 
    index=["Ventura County", "Kern County", "Inyo County", "San Diego County", "Orange County", "Riverside County", "San Bernardino County", "Imperial County"]
)

plotdata.plot(kind="bar")
plt.title("Los Angles Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
plt.savefig('output_data/los_angles_metro.png')

# %% [markdown]
# <font size=5>Florida</font>

# %%
fl_filter=data['State']=="FL"
fl_df=data[fl_filter]
# display(fl_df)

# %%
fl_percent_cols=fl_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
miami_counties=["Miami-Dade County", "Broward County", "Palm Beach County", "Monroe County", "Collier County", "Lee County", "Hendry County", "Glades County", "Okeechobee County", "Martin County"]

pre_covid=[]
covid=[]

for each_county in miami_counties:
    fl_cnt_filter=fl_percent_cols['RegionName']==each_county  #just change county name and run cell
    
    mar2017=fl_percent_cols.loc[fl_cnt_filter,'2017-03-31']
    feb2020=fl_percent_cols.loc[fl_cnt_filter,'2020-02-29']
    mar2020=fl_percent_cols.loc[fl_cnt_filter,'2020-03-31']
    dec2020=fl_percent_cols.loc[fl_cnt_filter,'2020-12-31']
    
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((((dec2020-mar2020)/dec2020)/10)*10)*100).values[0]

    pre_covid.append(pre_covid_annual)
    covid.append(covid_annual)

# display(pre_covid)
# display(covid)

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":[3.858112824417793,
 4.632071865443424,
 3.677937565449753,
 2.0843692348357563,
 0.21855784919605756,
 1.984270820747629,
 6.110635641676481,
 4.382965191653824,
 5.125313504020487,
 3.886453130631079],
    
    "During Covid Value Change":[4.907951881317499,
 6.404307842370917,
 5.5032167653990705,
 2.7183698633385234,
 5.855159676208327,
 5.326702594073939,
 3.683506895581199,
 2.7750719897614564,
 7.085551310103089,
 6.292197439905893]
    
    }, 
    index=["Miami-Dade County", "Broward County", "Palm Beach County", "Monroe County", "Collier County", "Lee County", "Hendry County", "Glades County", "Okeechobee County", "Martin County"]

)

plotdata.plot(kind="bar")
plt.title("Miami Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
plt.savefig('output_data/miami_metro_county.png')

# %% [markdown]
# <font size=5>Florida continued:</font>

# %%
file_path = "data/zhvi_data.csv"
home_values_df=pd.read_csv(file_path)

# home_values_df.head()

# %%
fl_filter=home_values_df['State']=="FL"
fl_df=home_values_df[fl_filter]
# display(fl_df)

# %%
# fl_df.describe()

# %%
price_columns= ['2017-01-31', '2017-02-28', '2017-03-31',
       '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
       '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
       '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30',
       '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
       '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
       '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
       '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29',
       '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
       '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31']

# %%
miami_dade_cnt_filter=home_values_df['RegionName']=="Miami-Dade County"

miami_dade_price_over_time=fl_df.loc[miami_dade_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,miami_dade_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Miami-Dade County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=275000, ymax=340000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/miami_dade_county.png')

plt.show()

# %%
broward_cnt_filter=home_values_df['RegionName']=="Broward County"

broward_price_over_time=fl_df.loc[broward_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,broward_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Broward County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=240000, ymax=300000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/broward_county.png')

plt.show()

# %%
palm_beach_cnt_filter=home_values_df['RegionName']=="Palm Beach County"

palm_beach_price_over_time=fl_df.loc[palm_beach_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,palm_beach_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Palm Beach County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=255000, ymax=315000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/palm_beach_county.png')

plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(price_columns,miami_dade_price_over_time.iloc[0], label="Miami-Dade County")
plt.plot(price_columns,broward_price_over_time.iloc[0], label="Broward County")
plt.plot(price_columns,palm_beach_price_over_time.iloc[0], label="Palm Beach County")

plt.legend()
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Florida County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=225000, ymax=345000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/highest_covid_counties_fl.png')

plt.show()

# %%
monroe_cnt_filter=home_values_df['RegionName']=="Monroe County"

monroe_price_over_time=fl_df.loc[monroe_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,monroe_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Monroe County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=570000, ymax=635000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/monroe_county.png')

plt.show()

# %%
collier_cnt_filter=home_values_df['RegionName']=="Collier County"

collier_price_over_time=fl_df.loc[collier_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,collier_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Collier County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=340000, ymax=365000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/collier_county.png')

plt.show()

# %%
lee_cnt_filter=home_values_df['RegionName']=="Lee County"

lee_price_over_time=fl_df.loc[lee_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,lee_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Lee County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=220000, ymax=255000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/lee_county.png')

plt.show()

# %%
hendry_cnt_filter=home_values_df['RegionName']=="Hendry County"

hendry_price_over_time=fl_df.loc[hendry_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,hendry_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Hendry County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=110000, ymax=145000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/hendry_county.png')

plt.show()

# %%
glades_cnt_filter=home_values_df['RegionName']=="Glades County"

glades_price_over_time=fl_df.loc[glades_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,glades_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Glades County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=115000, ymax=142000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/glades_county.png')

plt.show()

# %%
okeechobee_cnt_filter=home_values_df['RegionName']=="Okeechobee County"

okeechobee_price_over_time=fl_df.loc[okeechobee_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,okeechobee_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Okeechobee County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=140000, ymax=185000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/okeechobee_county.png')

plt.show()

# %%
martin_cnt_filter=home_values_df['RegionName']=="Martin County"

martin_price_over_time=fl_df.loc[martin_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,martin_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Martin County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.vlines('2020-02-29', ymin=260000, ymax=325000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')

plt.savefig('output_data/martin_city.png')

plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(price_columns,miami_dade_price_over_time.iloc[0], label="Miami-Dade County")
plt.plot(price_columns,broward_price_over_time.iloc[0], label="Broward County")
plt.plot(price_columns,palm_beach_price_over_time.iloc[0], label="Palm Beach County")
plt.plot(price_columns,monroe_price_over_time.iloc[0], label="Monroe County")
plt.plot(price_columns,collier_price_over_time.iloc[0], label="Collier County")
plt.plot(price_columns,lee_price_over_time.iloc[0], label="Lee County")
plt.plot(price_columns,hendry_price_over_time.iloc[0], label="Hendry County")
plt.plot(price_columns,glades_price_over_time.iloc[0], label="Glades County")
plt.plot(price_columns,okeechobee_price_over_time.iloc[0], label="Okeechobee County")
plt.plot(price_columns,martin_price_over_time.iloc[0], label="Martin County")
plt.vlines('2020-02-29', ymin=100000, ymax=650000, colors='gold',linestyles='dashed', label='Covid-19 Lockdowns Begin')
plt.legend(loc='upper left')
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Florida County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)

plt.savefig('output_data/all_counties_fl.png')

plt.show()

# %% [markdown]
# <font size=5>Texas</font>

# %%
file_path = "data/zhvi_data.csv"
home_values_df=pd.read_csv(file_path)

# home_values_df.head()

# %%
tx_filter=home_values_df['State']=="TX"
tx_df=home_values_df[tx_filter]
# display(tx_df)

# %%
# tx_df.describe()

# %%
price_columns= ['2017-01-31', '2017-02-28', '2017-03-31',
       '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
       '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
       '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31', '2018-06-30',
       '2018-07-31', '2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
       '2018-12-31', '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
       '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31', '2019-09-30',
       '2019-10-31', '2019-11-30', '2019-12-31', '2020-01-31', '2020-02-29',
       '2020-03-31', '2020-04-30', '2020-05-31', '2020-06-30', '2020-07-31',
       '2020-08-31', '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31']

# %%
tx_percent_cols=tx_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]

# tx_percent_cols

# %%
tx_percent_cols=tx_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
Dallas_counties=["Dallas County", "Tarrant County", "Denton County", "Collin County", "Rockwall County", "Hunt County", "Kaufman County", "Ellis County", "Johnson County", "Hood County", "Parker County", "Wise County"]

pre_covid_dfw=[]
covid_dfw=[]


for each_county in Dallas_counties:
    
    tx_cnt_filter=tx_percent_cols['RegionName']==each_county  #just change county name and run cell
    
    mar2017=tx_percent_cols.loc[tx_cnt_filter,'2017-03-31']
    feb2020=tx_percent_cols.loc[tx_cnt_filter,'2020-02-29']
    mar2020=tx_percent_cols.loc[tx_cnt_filter,'2020-03-31']
    dec2020=tx_percent_cols.loc[tx_cnt_filter,'2020-12-31']

   
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((dec2020-mar2020)/dec2020)*100).values[0]
    
    pre_covid_dfw.append(pre_covid_annual)
    covid_dfw.append(covid_annual)

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":pre_covid_dfw,
    "During Covid Value Change":covid_dfw
    }, 
    index=["Dallas County", "Tarrant County", "Denton County", "Collin County", "Rockwall County", "Hunt County", "Kaufman County", "Ellis County", "Johnson County", "Hood County", "Parker County", "Wise County"]
)
plotdata.plot(kind="bar")
plt.title("Dallas-Fort Worth Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
plt.ylim(0,12)

plt.savefig('data/dfw_metro.png')

# %%
tx_cnt_filter=home_values_df['RegionName']=="Dallas County"

Dallas_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Dallas_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Dallas County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()

plt.show()

plt.savefig('data/dallas_county.png')

# %%
tx_cnt_filter=home_values_df['RegionName']=="Tarrant County"

Tarrant_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Tarrant_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Tarrant County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()
plt.savefig('data/tarrant_county.png')

# %%
tx_cnt_filter=home_values_df['RegionName']=="Denton County"

Denton_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Denton_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Denton County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Collin County"

Collin_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns, Collin_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Collin County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Rockwall County"

Rockwall_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Rockwall_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Rockwall County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Hunt County"

Hunt_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Hunt_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Hunt County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Kaufman County"

Kaufman_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Kaufman_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Kaufman County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Ellis County"

Ellis_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Ellis_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Ellis County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Johnson County"

Johnson_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Johnson_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Johnson County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Hood County"

Hood_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Hood_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Hood County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Parker County"

Parker_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Parker_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Parker County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Wise County"

Wise_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Wise_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Wise County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_percent_cols=tx_df[['RegionName','2017-03-31', '2020-02-29', '2020-03-31', '2020-12-31']]
Houston_counties=["Harris County", "Montgomery County", "Liberty County", "Chambers County", "Galveston County", "Brazoria County", "Fort Bend County", "Waller County"]

pre_covid_houston=[]
covid_houston=[]


for each_county in Houston_counties:
    
    tx_cnt_filter=tx_percent_cols['RegionName']==each_county 
    
    mar2017=tx_percent_cols.loc[tx_cnt_filter,'2017-03-31']
    feb2020=tx_percent_cols.loc[tx_cnt_filter,'2020-02-29']
    mar2020=tx_percent_cols.loc[tx_cnt_filter,'2020-03-31']
    dec2020=tx_percent_cols.loc[tx_cnt_filter,'2020-12-31']

   
    pre_covid_annual=((((feb2020-mar2017)/feb2020)/3)*100).values[0]
    covid_annual=(((dec2020-mar2020)/dec2020)*100).values[0]
    
    pre_covid_houston.append(pre_covid_annual)
    covid_houston.append(covid_annual)

# %%
plotdata = pd.DataFrame({
    "Pre Covid Value Change Per Year":pre_covid_houston,
    "During Covid Value Change":covid_houston
    }, 
    index=["Harris County", "Montgomery County", "Liberty County", "Chambers County", "Galveston County", "Brazoria County", "Fort Bend County", "Waller County"]
)
plotdata.plot(kind="bar")
plt.title("Houston Metro County Home Values Percent Change Over Time")
plt.xlabel("County Name")
plt.ylabel("Percent Change")
plt.ylim(0,12)

plt.savefig('data/houston_metro.png')

plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Harris County"

harris_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,harris_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Harris County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

plt.savefig('data/harris_county.png')

# %%
tx_cnt_filter=home_values_df['RegionName']=="Montgomery County"

montgomery_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,montgomery_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Montgomery County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Liberty County"

liberty_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,liberty_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Liberty County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Chambers County"

Chambers_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Chambers_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Chambers County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Galveston County"

Galveston_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Galveston_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Galveston County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Brazoria County"

Brazoria_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Brazoria_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Brazoria County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Fort Bend County"

Fort_Bend_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Fort_Bend_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Fort Bend County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
tx_cnt_filter=home_values_df['RegionName']=="Waller County"

Waller_price_over_time=tx_df.loc[tx_cnt_filter, price_columns]

plt.figure(figsize=(12,8))
plt.plot(price_columns,Waller_price_over_time.iloc[0], marker="o")
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Waller County Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.plot(price_columns,harris_price_over_time.iloc[0], label="Harris County")
plt.plot(price_columns,montgomery_price_over_time.iloc[0], label="Montgomery County")
plt.plot(price_columns,liberty_price_over_time.iloc[0], label="Liberty County")
plt.plot(price_columns,Chambers_price_over_time.iloc[0], label="Chambers County")
plt.plot(price_columns,Galveston_price_over_time.iloc[0], label="Galveston County")
plt.plot(price_columns,Brazoria_price_over_time.iloc[0], label="Brazoria County")
plt.plot(price_columns,Fort_Bend_price_over_time.iloc[0], label="Fort Bend County")
plt.plot(price_columns,Waller_price_over_time.iloc[0], label="Waller County")
plt.legend()
plt.xlabel("Date", fontsize=10)
plt.ylabel("Zillow Home Value Index ($)")
plt.title("Houston Metro Home Values 2017-2020")
plt.xticks(fontsize=8,rotation=90)
plt.axvline('2020-02-29', label='Covid-19 Lockdowns Begin')

plt.legend()
plt.show()
